# %%
# %pwd
# Out:
# '/home/sagemaker-user/ReDEeP-ICLR-main'

# %%
# !pip install sentence_transformers
# Out:
# ...
#   Using cached sentence_transformers-4.0.2-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached sentence_transformers-4.0.2-py3-none-any.whl (340 kB)
# ...

# %%
# !pip install -e transformers
# Out:
# Obtaining file:///home/sagemaker-user/ReDEeP-ICLR-main/transformers
#   Installing build dependencies ... one
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... one
#   Preparing editable metadata (pyproject.toml) ... one
# ...
#   Using cached tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
# Using cached tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# ...
#   Building editable for transformers (pyproject.toml) ... one
#   Created wheel for transformers: filename=transformers-4.42.0.dev0-0.editable-py3-none-any.whl size=17397 sha256=792e19a3e5432f9d0ab21c6bc0c552f0f69dd2b29d61664b415648d0fcea5aba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5o0ri8bo/wheels/48/15/48/a6fbe6512527b873e2f5e31e19b3e8c209f2fcf58915e43f9b
# Successfully built transformers
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
# ...

# %%
# !python ./ReDeEP/chunk_level_detect.py --model_name llama2-7b --dataset ragtruth
# Out:
# 2025-04-09 04:57:23.402194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-09 04:57:23.418010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-09 04:57:23.423038: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-09 04:57:23.434439: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ./ReDeEP/token_level_detect.py --model_name llama2-7b --dataset ragtruth
# Out:
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:15<00:00,  7.67s/it]
# <s>[INST] <<SYS>>                                       | 0/100 [00:00<?, ?it/s]
# You are a helpful assistant.
# <</SYS>>
#
# Summarize the following news within 86 words:
# ...

# %%
# !python ./AARF/truthful_answer_generate.py --model_name llama2-7b --AARF
# Out:
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:02<00:00,  1.14s/it]
# input_ids torch.Size([1, 248])
#  Based on the provided track listing for The Story of June by Edmond Leung, the names of the songs that do not have Chinese names are:
#
# * "Love Blind" (戀愛盲)
# * "Get Away with Miriam Yeung" (滾)
#
# Therefore, the names of the songs in the album that have English names are:
#
# * "Love Blind"
# * "Get Away with Miriam Yeung"
#
# I hope this helps! Let me know if you have any other questions.
# input_ids torch.Size([1, 344])
#  Of the films listed, the following came out after 1948:
#
# * Gilda (1946)
# * Two Years Before the Mast (1946)
# * Secret Beyond the Door... (1947)
# * The Rose Tattoo (1955)
# * Lawman (1959 episode "The Outsider")
#
# Therefore, the answer to the question is: Gilda, Two Years Before the Mast, Secret Beyond the Door..., The Rose Tattoo, and Lawman (as Mrs. Lebeau).
# input_ids torch.Size([1, 575])
# ...

# %%
# !python ./AARF/truthful_answer_generate.py --model_name llama2-7b
# Out:
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:02<00:00,  1.14s/it]
# input_ids torch.Size([1, 248])
#  Based on the provided track listing, the names of the songs from The Story of June that do not have Chinese names are:
#
# * "Love Blind" (戀愛盲)
# * "Get Away with Miriam Yeung" (滾)
#
# Unable to answer based on given content.
# input_ids torch.Size([1, 344])
#  Of the films listed, the following came out after 1948:
#
# * Gilda (1946)
# * Two Years Before the Mast (1946)
# * Secret Beyond the Door... (1947)
# * The Rose Tattoo (1955)
# * Lawman (1959 episode "The Outsider")
#
# Therefore, the answer to the question is: Gilda, Two Years Before the Mast, Secret Beyond the Door..., The Rose Tattoo, and Lawman (as Mrs. Lebeau).
# input_ids torch.Size([1, 575])
#  Here is a list of American foods that are related to breeds:
#
# 1. Cheese - There are several breeds of cows that produce milk used in American cheeses, such as Holsteins, Jerseys, and Guernseys.
# ...

# %%
# !python ./AARF/truthful_evaluation.py --model_name llama2-7b
# Out:
# Attempt 1 failed. Retrying...                            | 0/30 [00:00<?, ?it/s]
# HTTPSConnectionPool(host='api2.aigcbest.top', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Unable to connect to proxy', ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f9e88738f90>, 'Connection to 10.74.176.8 timed out. (connect timeout=None)')))
